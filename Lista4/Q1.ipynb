# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/xrdippdk1c5ovv7/fake-file19.csv?dl=1")
print(df.sort_values(by=["Salario", "Idade"], ascending=[True, False]))
# Out:
#     Funcionario Escolaridade Genero  Idade  Meses  Salario
# 2             3     Fundam.1      F     18     75     1550
# 0             1     Fundam.1      M     72     18     1830
# 17           18     Superior      M     53     41     2490
# 5             6     Fundam.2      F     17     33     6270
# 8             9     Fundam.2      F     57     93     8460
# 3             4     Fundam.2      M     71     37    10200
# 19           20     Fundam.2      F     67     33    11400
# 13           14     Fundam.2      F     65     95    11660
# 14           15     Fundam.2      O     60     86    11800
# 15           16     Superior      F     23     19    12250
# 1             2     Fundam.1      F     53     36    15060
# 6             7     Fundam.1      M     57     85    15310
# 18           19     Fundam.2      F     20     96    15660
# 9            10     Superior      F     46     67    16950
# 4             5     Fundam.1      M     18      8    17320
# ...
