# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/gs16ryvchrtwlb3/fake-file10.csv?dl=1")
df = df.sort_values(by="Escolaridade")
print(df)
# Out:
#     Funcionario Escolaridade Genero  Idade  Meses  Salario
# 1             2     Fundam.1      F     67     86    13300
# 2             3     Fundam.1      F     55     40    10630
# 3             4     Fundam.1      M     65     99     6470
# 5             6     Fundam.1      F     20      0     6840
# 14           15     Fundam.1      O     41     37     2260
# 0             1     Fundam.2      M     20     48    13490
# 17           18     Fundam.2      F     69      6     9330
# 16           17     Fundam.2      M     52     22    17640
# 15           16     Fundam.2      O     53     83     6080
# 13           14     Fundam.2      F     55     66    19090
# 11           12     Fundam.2      F     31     91     7160
# 9            10     Fundam.2      F     71     41    15790
# 18           19     Fundam.2      M     40     71    16730
# 7             8     Fundam.2      F     34     48     6390
# 4             5     Fundam.2      F     49     74    16000
# 10           11     Fundam.2      F     56     50    10430
# 19           20     Fundam.2      F     70     23    10440
# 12           13     Superior      F     28     81     6580
# 8             9     Superior      M     68     73     6010
# 6             7     Superior      F     46     86    17760
