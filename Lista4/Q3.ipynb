# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/4dthpl0q8ynaqcr/fake-file15.csv?dl=1")

resultado = df["Funcionario"].mean()
print("%.2f" % resultado)
# Out:
# 10.50
