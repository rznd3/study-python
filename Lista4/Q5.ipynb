# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/qvhsd1mr7dddks5/fake-file04.csv?dl=1")
print(df[["Salario","Meses","Genero", "Funcionario"]].query("Salario < 9753 and Meses >= 51"))
# Out:
#     Salario  Meses Genero  Funcionario
# 2      2160     67      F            3
# 3      8010     78      M            4
# 4      1480     87      O            5
# 9      6740     53      F           10
# 12     6690     63      M           13
# 15     8820     79      F           16
# 16     6680     86      F           17
