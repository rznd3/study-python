# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/kdbsu1hyo7l2zhx/fake-file14.csv?dl=1")
print(df.query("Idade > 47"))
# Out:
#     Funcionario Escolaridade Genero  Idade  Meses  Salario
# 3             4     Superior      F     56     36    18760
# 4             5     Fundam.1      F     48      1    10580
# 5             6     Fundam.2      F     50     84    18030
# 6             7     Fundam.2      F     60     21    15040
# 7             8     Fundam.2      F     66     40     6200
# 8             9     Fundam.2      O     74     16    12150
# 11           12     Fundam.1      M     57     99     6590
# 14           15     Superior      M     59     91     6580
# 16           17     Fundam.1      F     71     75     4700
# 17           18     Fundam.2      F     49     33     3840
# 19           20     Fundam.2      M     57     23     7250
