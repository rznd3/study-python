# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# importando a biblioteca numpy para fazer a lista de números
import numpy as np 
# importando a biblioteca matplotlib.pyplot para fazer o grafico
import matplotlib.pyplot as plt 
# forma de exibicao do grafico
# %matplotlib inline 
# importando a biblioteca math para poder utilizar a funcao math.pi
import math

x = np.arange(0,8.1,0.1) # tempo

y = 200 + 120*np.sin(x*math.pi/2)

plt.plot(x, y) # desenho da funcao y

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("custo") # legenda do eixo y
# Out:
# Text(0, 0.5, 'custo')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
