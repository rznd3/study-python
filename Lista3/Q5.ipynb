# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# importando a biblioteca numpy para fazer a lista de números
import numpy as np 
# importando a biblioteca matplotlib.pyplot para fazer o grafico
import matplotlib.pyplot as plt 
# forma de exibicao do grafico
# %matplotlib inline 
# importando a biblioteca math para poder utilizar a funcao math.pi
import math

x = np.arange(0,16.1,0.1) # intervalo de tempo

a = 78 + 42 * np.cos(3*math.pi*x) # funcao a

plt.plot(x, a) # desenho da funcao a

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("eixo y") # legenda do eixo y
# Out:
# Text(0, 0.5, 'eixo y')

# %%
x = np.arange(0,16.1,0.1)

b = 99 + 21 * np.cos(3*math.pi*x)

plt.plot(x, b)

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("eixo y") # legenda do eixo y
# Out:
# Text(0, 0.5, 'eixo y')

# %%
x = np.arange(0,16.1,0.1)

c = 99 + 21 * np.cos(2*math.pi*x)

plt.plot(x, c)

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("eixo y") # legenda do eixo y
# Out:
# Text(0, 0.5, 'eixo y')

# %%
x = np.arange(0,16.1,0.1)

d = 78 + 42 * np.cos(x)

plt.plot(x, d)

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("eixo y") # legenda do eixo y
# Out:
# Text(0, 0.5, 'eixo y')

# %%
x = np.arange(0,16.1,0.1)

e = 99 + 21 * np.cos(x)

plt.plot(x, e)

plt.grid() # grade
plt.xlabel("tempo") # legenda do eixo x
plt.ylabel("eixo y") # legenda do eixo y
# Out:
# Text(0, 0.5, 'eixo y')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
