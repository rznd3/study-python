# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd  
df = pd.read_csv("https://www.dropbox.com/s/idtrbl7l7mkfkr3/Exames2.csv?dl=1") 
coluna_lida = input()  
corr = df['Exame 1'].corr(df[coluna_lida]) 
print("Coeficiente de correlação entre coluna Trabalho e",coluna_lida,"eh: %.2f"%corr)
# Out:
# Exame 2
# Coeficiente de correlação entre coluna Trabalho e Exame 2 eh: 0.79
