# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://www.dropbox.com/s/fspfiuvv3ywti5p/fake-classrooms14.csv?dl=1")

percentil = np.percentile(df["Prova 1"],q=55)
print("%.2f" %percentil)
# Out:
# 2.00
