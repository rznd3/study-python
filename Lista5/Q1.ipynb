# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/pk3nk4mafrerijl/fake-classrooms10.csv?dl=1")

df["Ponderada"] = df["Prova 1"]*3 + df["Prova 2"]*7

print(df)
# Out:
#                 Nome  Prova 1  Prova 2  Trabalho  Ponderada
# 0   Elizabeth Feller        1        4         9         31
# 1        Mark Stroik        2        7         7         55
# 2      James Mustafa        3        5         7         44
# 3        Troy Hunter        1        4         9         31
# 4   Francisco Mccool        3        7         6         58
# 5         Bessie Kut        4        5         8         47
# 6      Kurt Veenstra        1        5         9         38
# 7     Gloria Simpson        1        3         9         24
# 8        Anna Renaud        3        3         9         30
# 9     Dionne Fonseca        1        3        10         24
# 10    Gail Rodriguez        1        7         9         52
# 11      Sandra Smith        2        6         7         48
# 12   Annette Bartley        3        5         6         44
# 13       Cody Fisher        3        4         9         37
# 14    Claude Mankins        1        3         5         24
# 15      Damon Buford        2        3         6         27
# 16    Michael Croley        1        6         8         45
# 17      Jesus Horner        3        5         7         44
# 18   Mildred Plummer        1        6        10         45
# 19    Rafael Freeman        1        7        10         52
# 20       Warren Sevy        2        6         8         48
# 21    Felix Gardella        3        2         9         23
# 22         Mary Kaan        2        3         7         27
# 23      Leona Kizzee        1        6         8         45
# 24      Lois Spueler        3        5         7         44
# 25    Jarrod Shields        2        8         7         62
# 26    Melissa Harper        4        4         9         40
# 27     Deborah Smith        2        5         6         41
# 28       Janet Baker        1        6         9         45
# 29   Jeffrey Carlson        1        5         8         38
