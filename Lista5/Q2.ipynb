# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://www.dropbox.com/s/lsl61dvbd2gfg3n/fake-classrooms13.csv?dl=1")

Trabalho = input()
df_filtrada = df[Trabalho].mode()
print("%.2f" % df_filtrada)
# Out:
# Trabalho
# 9.00
